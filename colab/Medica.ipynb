# %% [markdown]
# <a href="https://colab.research.google.com/github/P4w3l22/MEDICA/blob/main/colab/Medica.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# System Medica+ - przykład

import pandas as pd

pacjenci = {
    "ID": [1, 2, 3],
    "Imię": ["Jan", "Anna", "Piotr"],
    "Nazwisko": ["Kowalski", "Nowak", "Wiśniewski"],
    "Wiek": [34, 28, 45]
}

df = pd.DataFrame(pacjenci)

print("Lista pacjentów:")
display(df)

print(f"\nLiczba pacjentów: {len(df)}")
